# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# 26/04/29 21:34:15 WARN Utils: Your hostname, ubuntu20 resolves to a loopback address: 127.0.1.1; using 192.168.1.100 instead (on interface enp0s3)
# 26/04/29 21:34:15 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/29 21:34:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv('/home/iosu/github-repos/pyspark_project/data/ventas.csv',
                    header=True,
                    inferSchema=True,
                    sep=",")

# %%
df.show()
# Out:
# +----------+--------+-----------+------+--------+---------+
# |     fecha|producto|  categoria|precio|cantidad|   ciudad|
# +----------+--------+-----------+------+--------+---------+
# |2024-01-01|Portátil|Electrónica|  1000|       1|   Madrid|
# |2024-01-02|   Ratón|Electrónica|    20|       2|Barcelona|
# |2024-01-03| Teclado|Electrónica|    50|       1|   Madrid|
# |2024-01-04|   Silla|      Hogar|   150|       1| Valencia|
# |2024-01-05|    Mesa|      Hogar|   300|       1|   Madrid|
# +----------+--------+-----------+------+--------+---------+

# %%
df.printSchema()
# Out:
# root
#  |-- fecha: date (nullable = true)
#  |-- producto: string (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- precio: integer (nullable = true)
#  |-- cantidad: integer (nullable = true)
#  |-- ciudad: string (nullable = true)

# %%
df.filter(df.precio > 500).show()
# Out:
# +----------+--------+-----------+------+--------+------+
# |     fecha|producto|  categoria|precio|cantidad|ciudad|
# +----------+--------+-----------+------+--------+------+
# |2024-01-01|Portátil|Electrónica|  1000|       1|Madrid|
# +----------+--------+-----------+------+--------+------+

# %%
df.groupBy(df.ciudad).sort(df.producto).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.groupBy(df.ciudad).sort(df.producto).show()
#
# AttributeError: 'GroupedData' object has no attribute 'sort'
